# %%
import os
os.chdir(r'C:\Users\Admin\Desktop\Multiple')

# %%
import pandas as pd
pd.read_csv('tip - Nameless.csv', names = ['total_bill', 'tip', 'sex', 'smoker', 'day', 'time','size'])
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       10.27  1.71    Male     No  Sun  Dinner     2
# 1       35.26  5.00  Female     No  Sun  Dinner     4
# 2       15.42  1.57    Male     No  Sun  Dinner     2
# 3       18.43  3.00    Male     No  Sun  Dinner     4
# 4       14.83  3.02  Female     No  Sun  Dinner     2
# 5       21.58  3.92    Male     No  Sun  Dinner     2
# 6       10.33  1.67  Female     No  Sun  Dinner     3
# 7       16.29  3.71    Male     No  Sun  Dinner     3
# 8       16.97  3.50  Female     No  Sun  Dinner     3
# 9       20.65  3.35    Male     No  Sat  Dinner     3

# %%
cols = ['total_bill', 'tip', 'sex', 'smoker', 'day', 'time','size']

# %%
import pandas as pd
pd.read_csv('tip - Nameless.csv', names = cols)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       10.27  1.71    Male     No  Sun  Dinner     2
# 1       35.26  5.00  Female     No  Sun  Dinner     4
# 2       15.42  1.57    Male     No  Sun  Dinner     2
# 3       18.43  3.00    Male     No  Sun  Dinner     4
# 4       14.83  3.02  Female     No  Sun  Dinner     2
# 5       21.58  3.92    Male     No  Sun  Dinner     2
# 6       10.33  1.67  Female     No  Sun  Dinner     3
# 7       16.29  3.71    Male     No  Sun  Dinner     3
# 8       16.97  3.50  Female     No  Sun  Dinner     3
# 9       20.65  3.35    Male     No  Sat  Dinner     3

# %%
pd.read_csv('tips1.csv', usecols=['total_bill', 'tip','day'])
# Out:
#    total_bill   tip  day
# 0       16.99  1.01  Sun
# 1       10.34  1.66  Sun
# 2       21.01  3.50  Sun
# 3       23.68  3.31  Sun
# 4       24.59  3.61  Sun
# 5       25.29  4.71  Sun
# 6        8.77  2.00  Sun
# 7       26.88  3.12  Sun
# 8       15.04  1.96  Sun
# 9       14.78  3.23  Sun

# %%
tips = pd.read_csv('tips1.csv', dtype={'size':'float32'})

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  10 non-null     float64
#  1   tip         10 non-null     float64
#  2   sex         10 non-null     object
#  3   smoker      10 non-null     object
#  4   day         10 non-null     object
#  5   time        10 non-null     object
#  6   size        10 non-null     float32
# dtypes: float32(1), float64(2), object(4)
# memory usage: 648.0+ bytes

# %%
tips = pd.read_csv('tip - NaN.csv', names=['total_bill','tip','sex','smoker','day', 'time','size'], 
                   na_values=['No','Dinner'])
tips.head()
# Out:
#    total_bill   tip     sex  smoker  day  time  size
# 0       10.27  1.71    Male     NaN  Sun   NaN     2
# 1       35.26  5.00  Female     NaN  Sun   NaN     4
# 2       15.42  1.57    Male     NaN  Sun   NaN     2
# 3       18.43  3.00    Male     NaN  Sun   NaN     4
# 4       14.83  3.02  Female     NaN  Sun   NaN     2

# %%
df = pd.DataFrame({'Category':['Furniture','Technology','Office Supplies'], 
             'sub category':[['Chair', 'Table'], ['Phone','Laptop'], ['Storage','Binders','Art']]})
df
# Out:
#           Category             sub category
# 0        Furniture           [Chair, Table]
# 1       Technology          [Phone, Laptop]
# 2  Office Supplies  [Storage, Binders, Art]

# %%
df.explode('sub category')
# Out:
#           Category sub category
# 0        Furniture        Chair
# 0        Furniture        Table
# 1       Technology        Phone
# 1       Technology       Laptop
# 2  Office Supplies      Storage
# 2  Office Supplies      Binders
# 2  Office Supplies          Art

# %%
df = pd.DataFrame({'Category':['Furniture','Technology','Office Supplies'], 
             'subcategory':['Chair,Table', 'Phone,Laptop', 'Storage,Binders,Art']})
df
# Out:
#           Category          subcategory
# 0        Furniture          Chair,Table
# 1       Technology         Phone,Laptop
# 2  Office Supplies  Storage,Binders,Art

# %%
df.assign(subcategory = df.subcategory.str.split(',')).explode('subcategory')
# Out:
#           Category subcategory
# 0        Furniture       Chair
# 0        Furniture       Table
# 1       Technology       Phone
# 1       Technology      Laptop
# 2  Office Supplies     Storage
# 2  Office Supplies     Binders
# 2  Office Supplies         Art

# %%
df = pd.DataFrame({'Category':['Furniture','Technology','Office Supplies'], 
             'subcategory':['Chair$Table', 'Phone$Laptop', 'Storage$Binders$Art']})
df
# Out:
#           Category          subcategory
# 0        Furniture          Chair$Table
# 1       Technology         Phone$Laptop
# 2  Office Supplies  Storage$Binders$Art

# %%
df.assign(subcategory = df.subcategory.str.split('$')).explode('subcategory')
# Out:
#           Category subcategory
# 0        Furniture       Chair
# 0        Furniture       Table
# 1       Technology       Phone
# 1       Technology      Laptop
# 2  Office Supplies     Storage
# 2  Office Supplies     Binders
# 2  Office Supplies         Art

# %%
avg_sales = tips.total_bill.mean()

# %%
avg_sales
# Out:
# 18.003

# %%
tips.query("total_bill > @avg_sales")
# Out:
#    total_bill   tip     sex  smoker  day  time  size
# 1       35.26  5.00  Female     NaN  Sun   NaN     4
# 3       18.43  3.00    Male     NaN  Sun   NaN     4
# 5       21.58  3.92    Male     NaN  Sun   NaN     2
# 9       20.65  3.35    Male     NaN  Sat   NaN     3

# %%
tips[tips['total_bill']>20]
# Out:
#    total_bill   tip     sex  smoker  day  time  size
# 1       35.26  5.00  Female     NaN  Sun   NaN     4
# 5       21.58  3.92    Male     NaN  Sun   NaN     2
# 9       20.65  3.35    Male     NaN  Sat   NaN     3

# %%
from pandas.api.types import CategoricalDtype

# %%
df = pd.DataFrame({'orderid':[1,2,3,4,5,6],
             'Manufacturer':['A','A','B','C','D','E'],
             'shipmode':['Same Day', '1st Class', '2nd Class', 'Standard Class', 'Same Day','2nd Class']})

# %%
type = CategoricalDtype(['Standard Class', '2nd Class', '1st Class', 'Same Day'], ordered = True)

# %%
type
# Out:
# CategoricalDtype(categories=['Standard Class', '2nd Class', '1st Class', 'Same Day'], ordered=True)

# %%
df['shipmode'] = df.shipmode.astypeype(type)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   orderid       6 non-null      int64
#  1   Manufacturer  6 non-null      object
#  2   shipmode      6 non-null      category
# dtypes: category(1), int64(1), object(1)
# memory usage: 422.0+ bytes

# %%
df.shipmode
# Out:
# 0          Same Day
# 1         1st Class
# 2         2nd Class
# 3    Standard Class
# 4          Same Day
# 5         2nd Class
# Name: shipmode, dtype: category
# Categories (4, object): [Standard Class < 2nd Class < 1st Class < Same Day]

# %%
df.sort_values('shipmode', ascending=False)
# Out:
#    orderid Manufacturer        shipmode
# 0        1            A        Same Day
# 4        5            D        Same Day
# 1        2            A       1st Class
# 2        3            B       2nd Class
# 5        6            E       2nd Class
# 3        4            C  Standard Class

# %%
df[df.shipmode> '2nd Class']
# Out:
#    orderid Manufacturer   shipmode
# 0        1            A   Same Day
# 1        2            A  1st Class
# 4        5            D   Same Day

# %%
tips.style.hide_index()
# Out:
# <style  type="text/css" >
# </style><table id="T_49fa88d8_e225_11ea_a129_30e37a58ac72" ><thead>    <tr>        <th class="col_heading level0 col0" >total_bill</th>        <th class="col_heading level0 col1" >tip</th>        <th class="col_heading level0 col2" >sex</th>        <th class="col_heading level0 col3" >smoker</th>        <th class="col_heading level0 col4" >day</th>        <th class="col_heading level0 col5" >time</th>        <th class="col_heading level0 col6" >size</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row0_col0" class="data row0 col0" >10.270000</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row0_col1" class="data row0 col1" >1.710000</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row0_col2" class="data row0 col2" >Male</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row0_col3" class="data row0 col3" >nan</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row0_col4" class="data row0 col4" >Sun</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row0_col5" class="data row0 col5" >nan</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row0_col6" class="data row0 col6" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row1_col0" class="data row1 col0" >35.260000</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row1_col1" class="data row1 col1" >5.000000</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row1_col2" class="data row1 col2" >Female</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row1_col3" class="data row1 col3" >nan</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row1_col4" class="data row1 col4" >Sun</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row1_col5" class="data row1 col5" >nan</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row1_col6" class="data row1 col6" >4</td>
#             </tr>
#             <tr>
#                                 <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row2_col0" class="data row2 col0" >15.420000</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row2_col1" class="data row2 col1" >1.570000</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row2_col2" class="data row2 col2" >Male</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row2_col3" class="data row2 col3" >nan</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row2_col4" class="data row2 col4" >Sun</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row2_col5" class="data row2 col5" >nan</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row2_col6" class="data row2 col6" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row3_col0" class="data row3 col0" >18.430000</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row3_col1" class="data row3 col1" >3.000000</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row3_col2" class="data row3 col2" >Male</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row3_col3" class="data row3 col3" >nan</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row3_col4" class="data row3 col4" >Sun</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row3_col5" class="data row3 col5" >nan</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row3_col6" class="data row3 col6" >4</td>
#             </tr>
#             <tr>
#                                 <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row4_col0" class="data row4 col0" >14.830000</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row4_col1" class="data row4 col1" >3.020000</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row4_col2" class="data row4 col2" >Female</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row4_col3" class="data row4 col3" >nan</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row4_col4" class="data row4 col4" >Sun</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row4_col5" class="data row4 col5" >nan</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row4_col6" class="data row4 col6" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row5_col0" class="data row5 col0" >21.580000</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row5_col1" class="data row5 col1" >3.920000</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row5_col2" class="data row5 col2" >Male</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row5_col3" class="data row5 col3" >nan</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row5_col4" class="data row5 col4" >Sun</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row5_col5" class="data row5 col5" >nan</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row5_col6" class="data row5 col6" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row6_col0" class="data row6 col0" >10.330000</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row6_col1" class="data row6 col1" >1.670000</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row6_col2" class="data row6 col2" >Female</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row6_col3" class="data row6 col3" >nan</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row6_col4" class="data row6 col4" >Sun</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row6_col5" class="data row6 col5" >nan</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row6_col6" class="data row6 col6" >3</td>
#             </tr>
#             <tr>
#                                 <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row7_col0" class="data row7 col0" >16.290000</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row7_col1" class="data row7 col1" >3.710000</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row7_col2" class="data row7 col2" >Male</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row7_col3" class="data row7 col3" >nan</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row7_col4" class="data row7 col4" >Sun</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row7_col5" class="data row7 col5" >nan</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row7_col6" class="data row7 col6" >3</td>
#             </tr>
#             <tr>
#                                 <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row8_col0" class="data row8 col0" >16.970000</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row8_col1" class="data row8 col1" >3.500000</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row8_col2" class="data row8 col2" >Female</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row8_col3" class="data row8 col3" >nan</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a58ac72row8_col4" class="data row8 col4" >Sun</td>
#                         <td id="T_49fa88d8_e225_11ea_a129_30e37a

# %%
tips.style.set_caption('This is my Tips data')
# Out:
# <style  type="text/css" >
# </style><table id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72" ><caption>This is my Tips data</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_bill</th>        <th class="col_heading level0 col1" >tip</th>        <th class="col_heading level0 col2" >sex</th>        <th class="col_heading level0 col3" >smoker</th>        <th class="col_heading level0 col4" >day</th>        <th class="col_heading level0 col5" >time</th>        <th class="col_heading level0 col6" >size</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row0_col0" class="data row0 col0" >10.270000</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row0_col1" class="data row0 col1" >1.710000</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row0_col2" class="data row0 col2" >Male</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row0_col3" class="data row0 col3" >nan</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row0_col4" class="data row0 col4" >Sun</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row0_col5" class="data row0 col5" >nan</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row0_col6" class="data row0 col6" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row1_col0" class="data row1 col0" >35.260000</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row1_col1" class="data row1 col1" >5.000000</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row1_col2" class="data row1 col2" >Female</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row1_col3" class="data row1 col3" >nan</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row1_col4" class="data row1 col4" >Sun</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row1_col5" class="data row1 col5" >nan</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row1_col6" class="data row1 col6" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row2_col0" class="data row2 col0" >15.420000</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row2_col1" class="data row2 col1" >1.570000</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row2_col2" class="data row2 col2" >Male</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row2_col3" class="data row2 col3" >nan</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row2_col4" class="data row2 col4" >Sun</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row2_col5" class="data row2 col5" >nan</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row2_col6" class="data row2 col6" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row3_col0" class="data row3 col0" >18.430000</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row3_col1" class="data row3 col1" >3.000000</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row3_col2" class="data row3 col2" >Male</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row3_col3" class="data row3 col3" >nan</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row3_col4" class="data row3 col4" >Sun</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row3_col5" class="data row3 col5" >nan</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row3_col6" class="data row3 col6" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row4_col0" class="data row4 col0" >14.830000</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row4_col1" class="data row4 col1" >3.020000</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row4_col2" class="data row4 col2" >Female</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row4_col3" class="data row4 col3" >nan</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row4_col4" class="data row4 col4" >Sun</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row4_col5" class="data row4 col5" >nan</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row4_col6" class="data row4 col6" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row5_col0" class="data row5 col0" >21.580000</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row5_col1" class="data row5 col1" >3.920000</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row5_col2" class="data row5 col2" >Male</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row5_col3" class="data row5 col3" >nan</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row5_col4" class="data row5 col4" >Sun</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row5_col5" class="data row5 col5" >nan</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row5_col6" class="data row5 col6" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row6_col0" class="data row6 col0" >10.330000</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row6_col1" class="data row6 col1" >1.670000</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row6_col2" class="data row6 col2" >Female</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row6_col3" class="data row6 col3" >nan</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row6_col4" class="data row6 col4" >Sun</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row6_col5" class="data row6 col5" >nan</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row6_col6" class="data row6 col6" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row7_col0" class="data row7 col0" >16.290000</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row7_col1" class="data row7 col1" >3.710000</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row7_col2" class="data row7 col2" >Male</td>
#                         <td id="T_5dc42f4c_e225_11ea_8c6d_30e37a58ac72row7_col3" class="data row7 col3" >nan</td>
#                         <td id="T

# %%
tips.style.hide_index().set_caption('This is a tips data table')
# Out:
# <style  type="text/css" >
# </style><table id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72" ><caption>This is a tips data table</caption><thead>    <tr>        <th class="col_heading level0 col0" >total_bill</th>        <th class="col_heading level0 col1" >tip</th>        <th class="col_heading level0 col2" >sex</th>        <th class="col_heading level0 col3" >smoker</th>        <th class="col_heading level0 col4" >day</th>        <th class="col_heading level0 col5" >time</th>        <th class="col_heading level0 col6" >size</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row0_col0" class="data row0 col0" >10.270000</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row0_col1" class="data row0 col1" >1.710000</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row0_col2" class="data row0 col2" >Male</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row0_col3" class="data row0 col3" >nan</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row0_col4" class="data row0 col4" >Sun</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row0_col5" class="data row0 col5" >nan</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row0_col6" class="data row0 col6" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row1_col0" class="data row1 col0" >35.260000</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row1_col1" class="data row1 col1" >5.000000</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row1_col2" class="data row1 col2" >Female</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row1_col3" class="data row1 col3" >nan</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row1_col4" class="data row1 col4" >Sun</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row1_col5" class="data row1 col5" >nan</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row1_col6" class="data row1 col6" >4</td>
#             </tr>
#             <tr>
#                                 <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row2_col0" class="data row2 col0" >15.420000</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row2_col1" class="data row2 col1" >1.570000</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row2_col2" class="data row2 col2" >Male</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row2_col3" class="data row2 col3" >nan</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row2_col4" class="data row2 col4" >Sun</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row2_col5" class="data row2 col5" >nan</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row2_col6" class="data row2 col6" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row3_col0" class="data row3 col0" >18.430000</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row3_col1" class="data row3 col1" >3.000000</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row3_col2" class="data row3 col2" >Male</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row3_col3" class="data row3 col3" >nan</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row3_col4" class="data row3 col4" >Sun</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row3_col5" class="data row3 col5" >nan</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row3_col6" class="data row3 col6" >4</td>
#             </tr>
#             <tr>
#                                 <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row4_col0" class="data row4 col0" >14.830000</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row4_col1" class="data row4 col1" >3.020000</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row4_col2" class="data row4 col2" >Female</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row4_col3" class="data row4 col3" >nan</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row4_col4" class="data row4 col4" >Sun</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row4_col5" class="data row4 col5" >nan</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row4_col6" class="data row4 col6" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row5_col0" class="data row5 col0" >21.580000</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row5_col1" class="data row5 col1" >3.920000</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row5_col2" class="data row5 col2" >Male</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row5_col3" class="data row5 col3" >nan</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row5_col4" class="data row5 col4" >Sun</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row5_col5" class="data row5 col5" >nan</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row5_col6" class="data row5 col6" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row6_col0" class="data row6 col0" >10.330000</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row6_col1" class="data row6 col1" >1.670000</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row6_col2" class="data row6 col2" >Female</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row6_col3" class="data row6 col3" >nan</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row6_col4" class="data row6 col4" >Sun</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row6_col5" class="data row6 col5" >nan</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row6_col6" class="data row6 col6" >3</td>
#             </tr>
#             <tr>
#                                 <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row7_col0" class="data row7 col0" >16.290000</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row7_col1" class="data row7 col1" >3.710000</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row7_col2" class="data row7 col2" >Male</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row7_col3" class="data row7 col3" >nan</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row7_col4" class="data row7 col4" >Sun</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row7_col5" class="data row7 col5" >nan</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row7_col6" class="data row7 col6" >3</td>
#             </tr>
#             <tr>
#                                 <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row8_col0" class="data row8 col0" >16.970000</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row8_col1" class="data row8 col1" >3.500000</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row8_col2" class="data row8 col2" >Female</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row8_col3" class="data row8 col3" >nan</td>
#                         <td id="T_7e175c86_e225_11ea_b3d4_30e37a58ac72row8_col4" class="data row8 col4" >Sun</td>

# %%
df = pd.DataFrame({'ID':[1,2,3,4],
             'Age':[32,23,33,23],
             'sex':['Male','Female','Female','Male'],
             'class':['1st Class', 'Standard Class', 'Same Day', 'Standard Class']})

# %%
df
# Out:
#    ID  Age     sex           class
# 0   1   32    Male       1st Class
# 1   2   23  Female  Standard Class
# 2   3   33  Female        Same Day
# 3   4   23    Male  Standard Class

# %%
pd.get_dummies(df, drop_first=True)
# Out:
#    ID  Age  sex_Male  class_Same Day  class_Standard Class
# 0   1   32         1               0                     0
# 1   2   23         0               0                     1
# 2   3   33         0               1                     0
# 3   4   23         1               0                     1

# %%
tips.loc[2,'sex']
# Out:
# 'Male'

# %%
tips.iloc[2,2]
# Out:
# 'Male'

# %%
tips.loc[2, tips.columns[1]]
# Out:
# 1.57

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
tips.loc[tips.index[1], 'sex']
# Out:
# 'Female'

# %%
tips
# Out:
#    total_bill   tip     sex  smoker  day  time  size
# 0       10.27  1.71    Male     NaN  Sun   NaN     2
# 1       35.26  5.00  Female     NaN  Sun   NaN     4
# 2       15.42  1.57    Male     NaN  Sun   NaN     2
# 3       18.43  3.00    Male     NaN  Sun   NaN     4
# 4       14.83  3.02  Female     NaN  Sun   NaN     2
# 5       21.58  3.92    Male     NaN  Sun   NaN     2
# 6       10.33  1.67  Female     NaN  Sun   NaN     3
# 7       16.29  3.71    Male     NaN  Sun   NaN     3
# 8       16.97  3.50  Female     NaN  Sun   NaN     3
# 9       20.65  3.35    Male     NaN  Sat   NaN     3

# %%
tips.iloc[tips.index.get_loc(2), 1]
# Out:
# 1.57

# %%
tips.iloc[2, tips.columns.get_loc('sex')]
# Out:
# 'Male'

# %%
df = pd.DataFrame({'Daily_Sales': [500,434,444,544], 
             'Weekly sales':[323,333,222,333]})

# %%
df
# Out:
#    Daily_Sales  Weekly sales
# 0          500           323
# 1          434           333
# 2          444           222
# 3          544           333

# %%
df.query('Daily_Sales> 500')
# Out:
#    Daily_Sales  Weekly_sales
# 3          544           333

# %%
df.query('`Weekly sales`> 300')
# Out:
#    Daily_Sales  Weekly sales
# 0          500           323
# 1          434           333
# 3          544           333

# %%
df = pd.DataFrame({'status':['order date', 'ship date', 'delivery date'],
             'month':[4, 4, 5], 'day':[25, 28, 4], 'year':[2020,2020,2020]})

# %%
df
# Out:
#           status  month  day  year
# 0     order date      4   25  2020
# 1      ship date      4   28  2020
# 2  delivery date      5    4  2020

# %%
df['Date'] = pd.to_datetime(df[['month','day','year']])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   status  3 non-null      object
#  1   month   3 non-null      int64
#  2   day     3 non-null      int64
#  3   year    3 non-null      int64
#  4   Date    3 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 248.0+ bytes

# %%
raw_data = {'cust_id':[1,2,3,4],
           'First Name':['A','B','C','D'],
           'Last Name':['P','Q','R','S']}

# %%
raw_data
# Out:
# {'cust_id': [1, 2, 3, 4],
#  'First Name': ['A', 'B', 'C', 'D'],
#  'Last Name': ['P', 'Q', 'R', 'S']}

# %%
raw_data1 = {'cust_id':[1,2,3,5],
           'Segment':['Py','Tab','SQL','Py'],
           'Sales':['250','200','200','250']}

# %%
cust_table = pd.DataFrame(raw_data)

# %%
sales_table = pd.DataFrame(raw_data1)

# %%
cust_table
# Out:
#    cust_id First Name Last Name
# 0        1          A         P
# 1        2          B         Q
# 2        3          C         R
# 3        4          D         S

# %%
sales_table
# Out:
#    cust_id Segment Sales
# 0        1      Py   250
# 1        2     Tab   200
# 2        3     SQL   200
# 3        5      Py   250

# %%
pd.merge(cust_table, sales_table, on='cust_id', how='outer', indicator=True)
# Out:
#    cust_id First Name Last Name Segment Sales      _merge
# 0        1          A         P      Py   250        both
# 1        2          B         Q     Tab   200        both
# 2        3          C         R     SQL   200        both
# 3        4          D         S     NaN   NaN   left_only
# 4        5        NaN       NaN      Py   250  right_only

# %%
tips
# Out:
#    total_bill   tip     sex  smoker  day  time  size
# 0       10.27  1.71    Male     NaN  Sun   NaN     2
# 1       35.26  5.00  Female     NaN  Sun   NaN     4
# 2       15.42  1.57    Male     NaN  Sun   NaN     2
# 3       18.43  3.00    Male     NaN  Sun   NaN     4
# 4       14.83  3.02  Female     NaN  Sun   NaN     2
# 5       21.58  3.92    Male     NaN  Sun   NaN     2
# 6       10.33  1.67  Female     NaN  Sun   NaN     3
# 7       16.29  3.71    Male     NaN  Sun   NaN     3
# 8       16.97  3.50  Female     NaN  Sun   NaN     3
# 9       20.65  3.35    Male     NaN  Sat   NaN     3

# %%
dict = {'total_bill': '${:.2f}', 'tip': '${:.2f}'}

# %%
tips.style.format(dict)
# Out:
# <style  type="text/css" >
# </style><table id="T_dbfc982e_e229_11ea_a116_30e37a58ac72" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >total_bill</th>        <th class="col_heading level0 col1" >tip</th>        <th class="col_heading level0 col2" >sex</th>        <th class="col_heading level0 col3" >smoker</th>        <th class="col_heading level0 col4" >day</th>        <th class="col_heading level0 col5" >time</th>        <th class="col_heading level0 col6" >size</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dbfc982e_e229_11ea_a116_30e37a58ac72level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row0_col0" class="data row0 col0" >$10.27</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row0_col1" class="data row0 col1" >$1.71</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row0_col2" class="data row0 col2" >Male</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row0_col3" class="data row0 col3" >nan</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row0_col4" class="data row0 col4" >Sun</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row0_col5" class="data row0 col5" >nan</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row0_col6" class="data row0 col6" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_dbfc982e_e229_11ea_a116_30e37a58ac72level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row1_col0" class="data row1 col0" >$35.26</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row1_col1" class="data row1 col1" >$5.00</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row1_col2" class="data row1 col2" >Female</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row1_col3" class="data row1 col3" >nan</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row1_col4" class="data row1 col4" >Sun</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row1_col5" class="data row1 col5" >nan</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row1_col6" class="data row1 col6" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_dbfc982e_e229_11ea_a116_30e37a58ac72level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row2_col0" class="data row2 col0" >$15.42</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row2_col1" class="data row2 col1" >$1.57</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row2_col2" class="data row2 col2" >Male</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row2_col3" class="data row2 col3" >nan</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row2_col4" class="data row2 col4" >Sun</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row2_col5" class="data row2 col5" >nan</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row2_col6" class="data row2 col6" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_dbfc982e_e229_11ea_a116_30e37a58ac72level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row3_col0" class="data row3 col0" >$18.43</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row3_col1" class="data row3 col1" >$3.00</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row3_col2" class="data row3 col2" >Male</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row3_col3" class="data row3 col3" >nan</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row3_col4" class="data row3 col4" >Sun</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row3_col5" class="data row3 col5" >nan</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row3_col6" class="data row3 col6" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_dbfc982e_e229_11ea_a116_30e37a58ac72level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row4_col0" class="data row4 col0" >$14.83</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row4_col1" class="data row4 col1" >$3.02</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row4_col2" class="data row4 col2" >Female</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row4_col3" class="data row4 col3" >nan</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row4_col4" class="data row4 col4" >Sun</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row4_col5" class="data row4 col5" >nan</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row4_col6" class="data row4 col6" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_dbfc982e_e229_11ea_a116_30e37a58ac72level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row5_col0" class="data row5 col0" >$21.58</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row5_col1" class="data row5 col1" >$3.92</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row5_col2" class="data row5 col2" >Male</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row5_col3" class="data row5 col3" >nan</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row5_col4" class="data row5 col4" >Sun</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row5_col5" class="data row5 col5" >nan</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row5_col6" class="data row5 col6" >2</td>
#             </tr>
#             <tr>
#                         <th id="T_dbfc982e_e229_11ea_a116_30e37a58ac72level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row6_col0" class="data row6 col0" >$10.33</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row6_col1" class="data row6 col1" >$1.67</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row6_col2" class="data row6 col2" >Female</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row6_col3" class="data row6 col3" >nan</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row6_col4" class="data row6 col4" >Sun</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row6_col5" class="data row6 col5" >nan</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row6_col6" class="data row6 col6" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_dbfc982e_e229_11ea_a116_30e37a58ac72level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row7_col0" class="data row7 col0" >$16.29</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row7_col1" class="data row7 col1" >$3.71</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row7_col2" class="data row7 col2" >Male</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row7_col3" class="data row7 col3" >nan</td>
#                         <td id="T_dbfc982e_e229_11ea_a116_30e37a58ac72row7_col4" class="data row7 col4" >Sun</td>

# %%
tips.style.format(dict).hide_index().highlight_min('total_bill', color='red').highlight_max('total_bill', color='green')
# Out:
# <style  type="text/css" >
#     #T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row0_col0 {
#             background-color:  red;
#             : ;
#         }    #T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row1_col0 {
#             : ;
#             background-color:  green;
#         }</style><table id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72" ><thead>    <tr>        <th class="col_heading level0 col0" >total_bill</th>        <th class="col_heading level0 col1" >tip</th>        <th class="col_heading level0 col2" >sex</th>        <th class="col_heading level0 col3" >smoker</th>        <th class="col_heading level0 col4" >day</th>        <th class="col_heading level0 col5" >time</th>        <th class="col_heading level0 col6" >size</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row0_col0" class="data row0 col0" >$10.27</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row0_col1" class="data row0 col1" >$1.71</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row0_col2" class="data row0 col2" >Male</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row0_col3" class="data row0 col3" >nan</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row0_col4" class="data row0 col4" >Sun</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row0_col5" class="data row0 col5" >nan</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row0_col6" class="data row0 col6" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row1_col0" class="data row1 col0" >$35.26</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row1_col1" class="data row1 col1" >$5.00</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row1_col2" class="data row1 col2" >Female</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row1_col3" class="data row1 col3" >nan</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row1_col4" class="data row1 col4" >Sun</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row1_col5" class="data row1 col5" >nan</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row1_col6" class="data row1 col6" >4</td>
#             </tr>
#             <tr>
#                                 <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row2_col0" class="data row2 col0" >$15.42</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row2_col1" class="data row2 col1" >$1.57</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row2_col2" class="data row2 col2" >Male</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row2_col3" class="data row2 col3" >nan</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row2_col4" class="data row2 col4" >Sun</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row2_col5" class="data row2 col5" >nan</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row2_col6" class="data row2 col6" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row3_col0" class="data row3 col0" >$18.43</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row3_col1" class="data row3 col1" >$3.00</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row3_col2" class="data row3 col2" >Male</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row3_col3" class="data row3 col3" >nan</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row3_col4" class="data row3 col4" >Sun</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row3_col5" class="data row3 col5" >nan</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row3_col6" class="data row3 col6" >4</td>
#             </tr>
#             <tr>
#                                 <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row4_col0" class="data row4 col0" >$14.83</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row4_col1" class="data row4 col1" >$3.02</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row4_col2" class="data row4 col2" >Female</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row4_col3" class="data row4 col3" >nan</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row4_col4" class="data row4 col4" >Sun</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row4_col5" class="data row4 col5" >nan</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row4_col6" class="data row4 col6" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row5_col0" class="data row5 col0" >$21.58</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row5_col1" class="data row5 col1" >$3.92</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row5_col2" class="data row5 col2" >Male</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row5_col3" class="data row5 col3" >nan</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row5_col4" class="data row5 col4" >Sun</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row5_col5" class="data row5 col5" >nan</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row5_col6" class="data row5 col6" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row6_col0" class="data row6 col0" >$10.33</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row6_col1" class="data row6 col1" >$1.67</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row6_col2" class="data row6 col2" >Female</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row6_col3" class="data row6 col3" >nan</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row6_col4" class="data row6 col4" >Sun</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row6_col5" class="data row6 col5" >nan</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row6_col6" class="data row6 col6" >3</td>
#             </tr>
#             <tr>
#                                 <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row7_col0" class="data row7 col0" >$16.29</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row7_col1" class="data row7 col1" >$3.71</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row7_col2" class="data row7 col2" >Male</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row7_col3" class="data row7 col3" >nan</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row7_col4" class="data row7 col4" >Sun</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row7_col5" class="data row7 col5" >nan</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row7_col6" class="data row7 col6" >3</td>
#             </tr>
#             <tr>
#                                 <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row8_col0" class="data row8 col0" >$16.97</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row8_col1" class="data row8 col1" >$3.50</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row8_col2" class="data row8 col2" >Female</td>
#                         <td id="T_7328a01e_e22a_11ea_a6cf_30e37a58ac72row8_col3" class="data row8 col3" >nan</td

# %%
tips.style.format(dict).hide_index().background_gradient(subset='total_bill', cmap='Greens')
# Out:
# <style  type="text/css" >
#     #T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row0_col0 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row1_col0 {
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }    #T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row2_col0 {
#             background-color:  #d2edcc;
#             color:  #000000;
#         }    #T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row3_col0 {
#             background-color:  #b0dfaa;
#             color:  #000000;
#         }    #T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row4_col0 {
#             background-color:  #d8f0d2;
#             color:  #000000;
#         }    #T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row5_col0 {
#             background-color:  #86cc85;
#             color:  #000000;
#         }    #T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row6_col0 {
#             background-color:  #f7fcf5;
#             color:  #000000;
#         }    #T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row7_col0 {
#             background-color:  #caeac3;
#             color:  #000000;
#         }    #T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row8_col0 {
#             background-color:  #c2e7bb;
#             color:  #000000;
#         }    #T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row9_col0 {
#             background-color:  #92d28f;
#             color:  #000000;
#         }</style><table id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72" ><thead>    <tr>        <th class="col_heading level0 col0" >total_bill</th>        <th class="col_heading level0 col1" >tip</th>        <th class="col_heading level0 col2" >sex</th>        <th class="col_heading level0 col3" >smoker</th>        <th class="col_heading level0 col4" >day</th>        <th class="col_heading level0 col5" >time</th>        <th class="col_heading level0 col6" >size</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row0_col0" class="data row0 col0" >$10.27</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row0_col1" class="data row0 col1" >$1.71</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row0_col2" class="data row0 col2" >Male</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row0_col3" class="data row0 col3" >nan</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row0_col4" class="data row0 col4" >Sun</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row0_col5" class="data row0 col5" >nan</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row0_col6" class="data row0 col6" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row1_col0" class="data row1 col0" >$35.26</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row1_col1" class="data row1 col1" >$5.00</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row1_col2" class="data row1 col2" >Female</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row1_col3" class="data row1 col3" >nan</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row1_col4" class="data row1 col4" >Sun</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row1_col5" class="data row1 col5" >nan</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row1_col6" class="data row1 col6" >4</td>
#             </tr>
#             <tr>
#                                 <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row2_col0" class="data row2 col0" >$15.42</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row2_col1" class="data row2 col1" >$1.57</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row2_col2" class="data row2 col2" >Male</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row2_col3" class="data row2 col3" >nan</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row2_col4" class="data row2 col4" >Sun</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row2_col5" class="data row2 col5" >nan</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row2_col6" class="data row2 col6" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row3_col0" class="data row3 col0" >$18.43</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row3_col1" class="data row3 col1" >$3.00</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row3_col2" class="data row3 col2" >Male</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row3_col3" class="data row3 col3" >nan</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row3_col4" class="data row3 col4" >Sun</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row3_col5" class="data row3 col5" >nan</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row3_col6" class="data row3 col6" >4</td>
#             </tr>
#             <tr>
#                                 <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row4_col0" class="data row4 col0" >$14.83</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row4_col1" class="data row4 col1" >$3.02</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row4_col2" class="data row4 col2" >Female</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row4_col3" class="data row4 col3" >nan</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row4_col4" class="data row4 col4" >Sun</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row4_col5" class="data row4 col5" >nan</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row4_col6" class="data row4 col6" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row5_col0" class="data row5 col0" >$21.58</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row5_col1" class="data row5 col1" >$3.92</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row5_col2" class="data row5 col2" >Male</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row5_col3" class="data row5 col3" >nan</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row5_col4" class="data row5 col4" >Sun</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row5_col5" class="data row5 col5" >nan</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row5_col6" class="data row5 col6" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row6_col0" class="data row6 col0" >$10.33</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row6_col1" class="data row6 col1" >$1.67</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row6_col2" class="data row6 col2" >Female</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row6_col3" class="data row6 col3" >nan</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row6_col4" class="data row6 col4" >Sun</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row6_col5" class="data row6 col5" >nan</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row6_col6" class="data row6 col6" >3</td>
#             </tr>
#             <tr>
#                                 <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row7_col0" class="data row7 col0" >$16.29</td>
#                         <td id="T_b65fbd7a_e22a_11ea_8d3b_30e37a58ac72row7_col1" class="data r

# %%
tips.style.format(dict).hide_index().bar('total_bill', color='Green', align='mid').set_caption('Total Bill Analysis')
# Out:
# <style  type="text/css" >
#     #T_fc0a586e_e22a_11ea_babf_30e37a58ac72row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,Green 29.1%, transparent 29.1%);
#         }    #T_fc0a586e_e22a_11ea_babf_30e37a58ac72row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,Green 100.0%, transparent 100.0%);
#         }    #T_fc0a586e_e22a_11ea_babf_30e37a58ac72row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,Green 43.7%, transparent 43.7%);
#         }    #T_fc0a586e_e22a_11ea_babf_30e37a58ac72row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,Green 52.3%, transparent 52.3%);
#         }    #T_fc0a586e_e22a_11ea_babf_30e37a58ac72row4_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,Green 42.1%, transparent 42.1%);
#         }    #T_fc0a586e_e22a_11ea_babf_30e37a58ac72row5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,Green 61.2%, transparent 61.2%);
#         }    #T_fc0a586e_e22a_11ea_babf_30e37a58ac72row6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,Green 29.3%, transparent 29.3%);
#         }    #T_fc0a586e_e22a_11ea_babf_30e37a58ac72row7_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,Green 46.2%, transparent 46.2%);
#         }    #T_fc0a586e_e22a_11ea_babf_30e37a58ac72row8_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,Green 48.1%, transparent 48.1%);
#         }    #T_fc0a586e_e22a_11ea_babf_30e37a58ac72row9_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,Green 58.6%, transparent 58.6%);
#         }</style><table id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72" ><caption>Total Bill Analysis</caption><thead>    <tr>        <th class="col_heading level0 col0" >total_bill</th>        <th class="col_heading level0 col1" >tip</th>        <th class="col_heading level0 col2" >sex</th>        <th class="col_heading level0 col3" >smoker</th>        <th class="col_heading level0 col4" >day</th>        <th class="col_heading level0 col5" >time</th>        <th class="col_heading level0 col6" >size</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row0_col0" class="data row0 col0" >$10.27</td>
#                         <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row0_col1" class="data row0 col1" >$1.71</td>
#                         <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row0_col2" class="data row0 col2" >Male</td>
#                         <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row0_col3" class="data row0 col3" >nan</td>
#                         <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row0_col4" class="data row0 col4" >Sun</td>
#                         <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row0_col5" class="data row0 col5" >nan</td>
#                         <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row0_col6" class="data row0 col6" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row1_col0" class="data row1 col0" >$35.26</td>
#                         <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row1_col1" class="data row1 col1" >$5.00</td>
#                         <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row1_col2" class="data row1 col2" >Female</td>
#                         <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row1_col3" class="data row1 col3" >nan</td>
#                         <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row1_col4" class="data row1 col4" >Sun</td>
#                         <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row1_col5" class="data row1 col5" >nan</td>
#                         <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row1_col6" class="data row1 col6" >4</td>
#             </tr>
#             <tr>
#                                 <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row2_col0" class="data row2 col0" >$15.42</td>
#                         <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row2_col1" class="data row2 col1" >$1.57</td>
#                         <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row2_col2" class="data row2 col2" >Male</td>
#                         <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row2_col3" class="data row2 col3" >nan</td>
#                         <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row2_col4" class="data row2 col4" >Sun</td>
#                         <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row2_col5" class="data row2 col5" >nan</td>
#                         <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row2_col6" class="data row2 col6" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row3_col0" class="data row3 col0" >$18.43</td>
#                         <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row3_col1" class="data row3 col1" >$3.00</td>
#                         <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row3_col2" class="data row3 col2" >Male</td>
#                         <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row3_col3" class="data row3 col3" >nan</td>
#                         <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row3_col4" class="data row3 col4" >Sun</td>
#                         <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row3_col5" class="data row3 col5" >nan</td>
#                         <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row3_col6" class="data row3 col6" >4</td>
#             </tr>
#             <tr>
#                                 <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row4_col0" class="data row4 col0" >$14.83</td>
#                         <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row4_col1" class="data row4 col1" >$3.02</td>
#                         <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row4_col2" class="data row4 col2" >Female</td>
#                         <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row4_col3" class="data row4 col3" >nan</td>
#                         <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row4_col4" class="data row4 col4" >Sun</td>
#                         <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row4_col5" class="data row4 col5" >nan</td>
#                         <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row4_col6" class="data row4 col6" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row5_col0" class="data row5 col0" >$21.58</td>
#                         <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row5_col1" class="data row5 col1" >$3.92</td>
#                         <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row5_col2" class="data row5 col2" >Male</td>
#                         <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row5_col3" class="data row5 col3" >nan</td>
#                         <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row5_col4" class="data row5 col4" >Sun</td>
#                         <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row5_col5" class="data row5 col5" >nan</td>
#                         <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row5_col6" class="data row5 col6" >2</td>
#             </tr>
#             <tr>
#                                 <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row6_col0" class="data row6 col0" >$10.33</td>
#                         <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row6_col1" class="data row6 col1" >$1.67</td>
#                         <td id="T_fc0a586e_e22a_11ea_babf_30e37a58ac72row6_col2" class="data row6 col2" >Female</td>
#                         <td
