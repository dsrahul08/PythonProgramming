# %%
import os
os.chdir(r'C:\Users\Rahul\Desktop')

# %%
import pandas as pd
df = pd.read_csv('tips.csv')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
import cx_Oracle
create_table = "create table hotel_dimension (total_bill number(10,2), tip number(10,2), sex varchar2(10), smoker varchar2(10), day varchar2(10), time varchar2(10), dsize number)"
con = cx_Oracle.connect('hr/atharv2210@localhost:1521/ORCL')
cur = con.cursor()
cur.execute('Drop table hotel_dimension')
cur.execute(create_table)
rows = [tuple(x) for x in df.values]
cur.executemany("insert into hotel_dimension (total_bill, tip, sex,smoker,day,time,dsize) values (:1,:2,:3,:4,:5,:6,:7)", rows)
con.commit()
cur.close()
con.close()

# %%
len(rows)
# Out:
# 244

# %%
import cx_Oracle
#create_table = "alter table hotel_dimension add  discount int"
con = cx_Oracle.connect('hr/atharv2210@localhost:1521/ORCL')
cur = con.cursor()
discount = int(input('Enter the discount'))
total_bill_range = float(input('Enter the total_bill range'))
query = "update hotel_dimension set discount = %d where total_bill > %f"
cur.execute(query %(discount, total_bill_range))
con.commit()
print('Records updated successfully')
cur.close()
con.close()
# Out:
# Enter the discount4
# Enter the total_bill range45.00
# Records updated successfully

# %%
import cx_Oracle
#create_table = "alter table hotel_dimension add  discount int"
con = cx_Oracle.connect('hr/atharv2210@localhost:1521/ORCL')
cur = con.cursor()
smoker_val = input('Enter the value')
query = "delete from hotel_dimension where smoker = '%s'"
cur.execute(query %smoker_val)
con.commit()
print('Records deleted successfully')
cur.close()
con.close()
# Out:
# Enter the valueYes
# Records deleted successfully

# %%
import cx_Oracle
#create_table = "alter table hotel_dimension add  discount int"
con = cx_Oracle.connect('hr/atharv2210@localhost:1521/ORCL')
cur = con.cursor()
query = "select * from hotel_dimension"
cur.execute(query)
row = cur.fetchone()
while row is not None:
    print(row)
    row = cur.fetchone()
    import time
    time.sleep(1)
cur.close()
con.close()
# Out:
# (16.99, 1.01, 'Female', 'No', 'Sun', 'Dinner', 2, None)
# (10.34, 1.66, 'Male', 'No', 'Sun', 'Dinner', 3, None)
# (21.01, 3.5, 'Male', 'No', 'Sun', 'Dinner', 3, None)
# (23.68, 3.31, 'Male', 'No', 'Sun', 'Dinner', 2, None)
# (24.59, 3.61, 'Female', 'No', 'Sun', 'Dinner', 4, None)
# (25.29, 4.71, 'Male', 'No', 'Sun', 'Dinner', 4, None)
# (8.77, 2.0, 'Male', 'No', 'Sun', 'Dinner', 2, None)
# (26.88, 3.12, 'Male', 'No', 'Sun', 'Dinner', 4, None)
# (15.04, 1.96, 'Male', 'No', 'Sun', 'Dinner', 2, None)
# (14.78, 3.23, 'Male', 'No', 'Sun', 'Dinner', 2, None)
# (10.27, 1.71, 'Male', 'No', 'Sun', 'Dinner', 2, None)
# (35.26, 5.0, 'Female', 'No', 'Sun', 'Dinner', 4, None)
# (15.42, 1.57, 'Male', 'No', 'Sun', 'Dinner', 2, None)
# (18.43, 3.0, 'Male', 'No', 'Sun', 'Dinner', 4, None)
# (14.83, 3.02, 'Female', 'No', 'Sun', 'Dinner', 2, None)
# (21.58, 3.92, 'Male', 'No', 'Sun', 'Dinner', 2, None)
# (10.33, 1.67, 'Female', 'No', 'Sun', 'Dinner', 3, None)
# ...

# %%
import cx_Oracle
#create_table = "alter table hotel_dimension add  discount int"
con = cx_Oracle.connect('hr/atharv2210@localhost:1521/ORCL')
cur = con.cursor()
query = "select * from hotel_dimension"
cur.execute(query)
data = cur.fetchall()
print(data)
cur.close()
con.close()
# Out:
# [(16.99, 1.01, 'Female', 'No', 'Sun', 'Dinner', 2, None), (10.34, 1.66, 'Male', 'No', 'Sun', 'Dinner', 3, None), (21.01, 3.5, 'Male', 'No', 'Sun', 'Dinner', 3, None), (23.68, 3.31, 'Male', 'No', 'Sun', 'Dinner', 2, None), (24.59, 3.61, 'Female', 'No', 'Sun', 'Dinner', 4, None), (25.29, 4.71, 'Male', 'No', 'Sun', 'Dinner', 4, None), (8.77, 2.0, 'Male', 'No', 'Sun', 'Dinner', 2, None), (26.88, 3.12, 'Male', 'No', 'Sun', 'Dinner', 4, None), (15.04, 1.96, 'Male', 'No', 'Sun', 'Dinner', 2, None), (14.78, 3.23, 'Male', 'No', 'Sun', 'Dinner', 2, None), (10.27, 1.71, 'Male', 'No', 'Sun', 'Dinner', 2, None), (35.26, 5.0, 'Female', 'No', 'Sun', 'Dinner', 4, None), (15.42, 1.57, 'Male', 'No', 'Sun', 'Dinner', 2, None), (18.43, 3.0, 'Male', 'No', 'Sun', 'Dinner', 4, None), (14.83, 3.02, 'Female', 'No', 'Sun', 'Dinner', 2, None), (21.58, 3.92, 'Male', 'No', 'Sun', 'Dinner', 2, None), (10.33, 1.67, 'Female', 'No', 'Sun', 'Dinner', 3, None), (16.29, 3.71, 'Male', 'No', 'Sun', 'Dinner', 3, None), (1
# ...

# %%
import cx_Oracle
#create_table = "alter table hotel_dimension add  discount int"
con = cx_Oracle.connect('hr/atharv2210@localhost:1521/ORCL')
cur = con.cursor()
query = "select * from hotel_dimension"
cur.execute(query)
data = cur.fetchall()
for row in data:
    print('Total_Bill:', row[0])
    print('Tip:', row[1])
    print('Sex:', row[2])
    print('Smoker:', row[3])
    print('Day:', row[4])
    print('Time:', row[5])
    print('Dsize:', row[6])
    print('Discount:', row[7])
    print()
cur.close()
con.close()
# Out:
# Total_Bill: 16.99
# Tip: 1.01
# Sex: Female
# Smoker: No
# Day: Sun
# Time: Dinner
# Dsize: 2
# Discount: None
#
# Total_Bill: 10.34
# Tip: 1.66
# Sex: Male
# Smoker: No
# Day: Sun
# Time: Dinner
# Dsize: 3
# Discount: None
#
# Total_Bill: 21.01
# Tip: 3.5
# Sex: Male
# Smoker: No
# Day: Sun
# Time: Dinner
# Dsize: 3
# Discount: None
#
# Total_Bill: 23.68
# Tip: 3.31
# Sex: Male
# Smoker: No
# Day: Sun
# Time: Dinner
# Dsize: 2
# Discount: None
#
# Total_Bill: 24.59
# Tip: 3.61
# Sex: Female
# Smoker: No
# Day: Sun
# Time: Dinner
# Dsize: 4
# Discount: None
#
# Total_Bill: 25.29
# Tip: 4.71
# Sex: Male
# Smoker: No
# Day: Sun
# Time: Dinner
# Dsize: 4
# Discount: None
#
# Total_Bill: 8.77
# Tip: 2.0
# Sex: Male
# Smoker: No
# Day: Sun
# Time: Dinner
# Dsize: 2
# Discount: None
#
# Total_Bill: 26.88
# Tip: 3.12
# Sex: Male
# Smoker: No
# Day: Sun
# Time: Dinner
# Dsize: 4
# Discount: None
#
# Total_Bill: 15.04
# Tip: 1.96
# Sex: Male
# Smoker: No
# Day: Sun
# Time: Dinner
# Dsize: 2
# ...

# %%
import cx_Oracle
#create_table = "alter table hotel_dimension add  discount int"
con = cx_Oracle.connect('hr/atharv2210@localhost:1521/ORCL')
cur = con.cursor()
query = "select * from hotel_dimension"
cur.execute(query)
n = int(input('Enter the no of rows required'))
data = cur.fetchmany(n)
for row in data:
    print('Total_Bill:', row[0])
    print('Tip:', row[1])
    print('Sex:', row[2])
    print('Smoker:', row[3])
    print('Day:', row[4])
    print('Time:', row[5])
    print('Dsize:', row[6])
    print('Discount:', row[7])
    print()
cur.close()
con.close()
# Out:
# Enter the no of rows required3
# Total_Bill: 16.99
# Tip: 1.01
# Sex: Female
# Smoker: No
# Day: Sun
# Time: Dinner
# Dsize: 2
# Discount: None
#
# Total_Bill: 10.34
# Tip: 1.66
# Sex: Male
# Smoker: No
# Day: Sun
# Time: Dinner
# Dsize: 3
# Discount: None
#
# Total_Bill: 21.01
# Tip: 3.5
# Sex: Male
# Smoker: No
# Day: Sun
# Time: Dinner
# Dsize: 3
# Discount: None

# %%
import cx_Oracle
#create_table = "alter table hotel_dimension add  discount int"
con = cx_Oracle.connect('hr/atharv2210@localhost:1521/ORCL')
cur = con.cursor()
query = "select * from hotel_dimension"
cur.execute(query)
n = int(input('Enter the no of rows required'))
data = cur.fetchmany(n)
f = open('dbresults.txt','w')
f.writelines(str(data))
cur.close()
con.close()
# Out:
# Enter the no of rows required2

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Rahul\\Desktop'
